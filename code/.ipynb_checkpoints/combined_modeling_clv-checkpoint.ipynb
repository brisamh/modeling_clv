# %% [markdown]
# # Customer Lifetime Value: Modeling Customer Profile for Underwriting Optimization
# ### The goal of this project is to create a model that predicts the customer lifetime values (CLV) of a given customer profile for auto insurance underwriting.

# %% [markdown]
# ## Load the data set and import libraries

# %%
## import pandas, numpy, and matplotlib
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

#Import sklearn
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

import statsmodels.api as sm
import statsmodels.formula.api as smf

#set plotting style
sns.set_style('whitegrid')

# %%
clv_df = pd.read_csv(
    'https://raw.githubusercontent.com/brisamh/modeling_clv/refs/heads/bhalviatti/data/clean_clv_data.csv')

# %%
clv_df.head()
# Out:
#   customer       state  customer_lifetime_value customer_response_to_offer  \
# 0  BU79786  Washington              2763.519279                         No
# 1  QZ44356     Arizona              6979.535903                         No
# 2  AI49188      Nevada             12887.431650                         No
# 3  WW63253  California              7645.861827                         No
# 4  HB64268  Washington              2813.692575                         No
#
#    coverage education policy_expiration_date employment_status gender  income  \
# 0     Basic  Bachelor             2011-02-24          Employed      F   56274
# 1  Extended  Bachelor             2011-01-31        Unemployed      F       0
# 2   Premium  Bachelor             2011-02-19          Employed      F   48767
# 3     Basic  Bachelor             2011-01-20        Unemployed      M       0
# 4     Basic  Bachelor             2011-02-03          Employed      M   43836
#
#    ... months_since_policy_inception number_of_open_complaints  \
# 0  ...                             5                         0
# 1  ...                            42                         0
# 2  ...                            38                         0
# 3  ...                            65                         0
# 4  ...                            44                         0
#
#    number_of_policies     policy_type        policy  renew_offer_type  \
# 0                   1  Corporate Auto  Corporate L3            Offer1
# 1                   8   Personal Auto   Personal L3            Offer3
# 2                   2   Personal Auto   Personal L3            Offer1
# 3                   7  Corporate Auto  Corporate L2            Offer1
# 4                   1   Personal Auto   Personal L1            Offer1
#
#    sales_channel total_claim_amount  vehicle_class vehicle_size
# 0          Agent         384.811147   Two-Door Car      Medsize
# 1          Agent        1131.464935  Four-Door Car      Medsize
# 2          Agent         566.472247   Two-Door Car      Medsize
# 3    Call Center         529.881344            SUV      Medsize
# 4          Agent         138.130879  Four-Door Car      Medsize
#
# [5 rows x 24 columns]

# %% [markdown]
# ## Model 1) Linear Regression: All Predictors Used

# %% [markdown]
# #### Before fitting the model we will drop data we do not need and perform one-hot encoding of categorical variables

# %%
clv_df = clv_df.drop(columns = ['customer', 'policy_expiration_date'])

# %% [markdown]
# We will convert the categorical variables to dummies dropping the first variable in each category.

# %%
clv_df_model_1 = clv_df
clv_df_model_1 = pd.get_dummies(clv_df_model_1, drop_first=True)

# %% [markdown]
# Find all columns in  clv_df that have the Boolean data type and convert them to 0 and 1.

# %%
bool_cols = clv_df_model_1.select_dtypes(include='bool').columns
clv_df_model_1[bool_cols] = clv_df_model_1[bool_cols].astype(int)

# %% [markdown]
# Create OLS model using all predictors available

# %%
X_1 = clv_df_model_1.drop(columns = 'customer_lifetime_value') 
y_1 = clv_df_model_1['customer_lifetime_value']

# %%
X_1 = sm.add_constant(X_1)
model_1 = sm.OLS(y_1, X_1).fit()
print(model_1.summary())
# Out:
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     customer_lifetime_value   R-squared:                       0.169
# Model:                                 OLS   Adj. R-squared:                  0.165
# Method:                      Least Squares   F-statistic:                     38.60
# Date:                     Wed, 19 Nov 2025   Prob (F-statistic):          6.92e-323
# Time:                             19:17:35   Log-Likelihood:                -92812.
# No. Observations:                     9134   AIC:                         1.857e+05
# Df Residuals:                         9085   BIC:                         1.861e+05
# Df Model:                               48
# Covariance Type:                 nonrobust
# ===================================================================================================
#                                       coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------
# const                
# renew_offer_type_Offer3          -535.2550    200.282     -2.673      0.008    -927.853    -142.657
# renew_offer_type_Offer4         -1196.6484    233.357     -5.128      0.000   -1654.080    -739.217
# sales_channel_Branch              227.6845    164.822      1.381      0.167     -95.404     550.773
# sales_channel_Call Center         350.0434    186.196      1.880      0.060     -14.942     715.029
# sales_channel_Web                  56.3085    206.103      0.273      0.785    -347.701     460.318
# vehicle_class_Luxury Car         1193.8204   1384.216      0.862      0.388   -1519.555    3907.196
# vehicle_class_Luxury SUV         1160.9889   1372.147      0.846      0.398   -1528.728    3850.706
# vehicle_class_SUV                 790.4905    457.031      1.730      0.084    -105.394    1686.375
# vehicle_class_Sports Car         1020.0479    526.252      1.938      0.053     -11.524    2051.620
# vehicle_class_Two-Door Car        110.3101    172.088      0.641      0.522    -227.021     447.642
# vehicle_size_Medsize              304.2439    219.734      1.385      0.166    -126.483     734.971
# vehicle_size_Small                438.6969    255.673      1.716      0.086     -62.480     939.874
# ==============================================================================
# Omnibus:                     5666.276   Durbin-Watson:                   1.995
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            65051.545
# Skew:                           2.849   Prob(JB):                         0.00
# Kurtosis:                      14.767   Cond. No.                     1.29e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.29e-19. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %%
print(model_1.pvalues[model_1.pvalues < 0.05].drop('const', errors='ignore'))
# Out:
# monthly_premium_auto              4.187587e-12
# number_of_open_complaints         2.686336e-04
# number_of_policies                3.759583e-02
# education_High School or Below    2.491937e-02
# employment_status_Employed        4.818648e-02
# marital_status_Single             2.972820e-02
# policy_Corporate L2               1.662197e-02
# renew_offer_type_Offer2           5.389205e-09
# renew_offer_type_Offer3           7.542192e-03
# renew_offer_type_Offer4           2.989086e-07
# dtype: float64

# %% [markdown]
# ### Model 1 Interpretation:
# * We have included all the variables in our model to begin with, but the R-Squared is only 0.169
# * Of 49 variables, only 10 were statistically significant (p-value < 0.05)
# * We did not include any interaction terms, despite seeing a 'stripe' effect in our data that indicates variable interactions

# %% [markdown]
# ## Model 2) Linear Regression: Removing CLV Outliers

# %% [markdown]
# As noted in our EDA, there is a lot of variablity in CLV specifically for customers with two policies. We will explore dropping CLV when it is outside the bounds of the 75th percentile of the two policy group, then re-modeling the data without these outliers:

# %%
clv_df[clv_df['number_of_policies'] == 2].describe()
# Out:
#        customer_lifetime_value        income  monthly_premium_auto  \
# count              2294.000000   2294.000000           2294.000000
# mean              15723.177937  37001.553182             93.261552
# std                9300.866249  30051.712074             33.426835
# min                5409.955926      0.000000             61.000000
# 25%                8642.421929      0.000000             68.250000
# 50%               12876.687620  33551.000000             85.000000
# 75%               19916.955327  61108.000000            109.000000
# max               83325.381190  99875.000000            295.000000
#
#        months_since_last_claim  months_since_policy_inception  \
# count              2294.000000                    2294.000000
# mean                 15.044900                      47.812554
# std                   9.996519                      27.948144
# min                   0.000000                       0.000000
# 25%                   6.000000                      23.000000
# 50%                  14.000000                      48.000000
# 75%                  23.000000                      71.000000
# max                  35.000000                      99.000000
#
#        number_of_open_complaints  number_of_policies  total_claim_amount
# count                2294.000000              2294.0         2294.000000
# mean                    0.364429                 2.0          433.610653
# std                     0.858842                 0.0          282.363856
# min                     0.000000                 2.0            1.489470
# 25%                     0.000000                 2.0          276.103498
# 50%                     0.000000                 2.0          393.600000
# 75%                     0.000000                 2.0          547.031224
# max                     5.000000                 2.0         2552.343856

# %% [markdown]
# We see above that 75% = 19916.955327 for customers with two policies. Returning to the full dataset, we will drop all records where the CLV exceeds this amount and re-model the data similar to how we performed model 1:

# %%
model_2 = clv_df_model_1[clv_df_model_1['customer_lifetime_value'] <= 19916]

# %%
X_2 = model_2.drop(columns = 'customer_lifetime_value')
y_2 = model_2['customer_lifetime_value']

# %%
X_2 = sm.add_constant(X_2)
model_2 = sm.OLS(y_2, X_2).fit()
print(model_2.summary())
# Out:
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:
# policy_Personal L1                -49.1737     87.320     -0.563      0.573    -220.342     121.995
# policy_Personal L2                -55.8318     76.019     -0.734      0.463    -204.848      93.185
# policy_Personal L3               -139.6800     68.935     -2.026      0.043    -274.809      -4.552
# policy_Special L1                 160.7765    333.007      0.483      0.629    -491.999     813.552
# policy_Special L2                -187.4463    238.755     -0.785      0.432    -655.464     280.571
# policy_Special L3                  52.7932    248.762      0.212      0.832    -434.841     540.428
# renew_offer_type_Offer2          -642.6605     88.403     -7.270      0.000    -815.952    -469.369
# renew_offer_type_Offer3          -381.7116    107.429     -3.553      0.000    -592.298    -171.125
# renew_offer_type_Offer4          -811.2565    124.549     -6.514      0.000   -1055.403    -567.110
# sales_channel_Branch             -116.0779     88.454     -1.312      0.189    -289.469      57.313
# sales_channel_Call Center          85.0627     99.511      0.855      0.393    -110.003     280.128
# sales_channel_Web                 -27.7318    109.896     -0.252      0.801    -243.155     187.691
# vehicle_class_Luxury Car          576.7587    775.576      0.744      0.457    -943.558    2097.075
# vehicle_class_Luxury SUV          453.5495    768.683      0.590      0.555   -1053.256    1960.355
# vehicle_class_SUV                 701.7632    254.338      2.759      0.006     203.200    1200.327
# vehicle_class_Sports Car          444.5336    290.767      1.529      0.126    -125.441    1014.508
# vehicle_class_Two-Door Car        126.5271     91.012      1.390      0.164     -51.878     304.932
# vehicle_size_Medsize              212.0705    117.298      1.808      0.071     -17.863     442.004
# vehicle_size_Small                291.2197    136.701      2.130      0.033      23.252     559.187
# ==============================================================================
# Omnibus:                     2834.495   Durbin-Watson:                   1.988
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             8406.490
# Skew:                           1.747   Prob(JB):                         0.00
# Kurtosis:                       6.374   Cond. No.                     1.29e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.21e-19. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %%
print(model_2.pvalues[model_2.pvalues < 0.05].drop('const', errors='ignore'))
# Out:
# monthly_premium_auto         2.358791e-14
# number_of_open_complaints    7.639587e-05
# number_of_policies           3.645461e-84
# coverage_Premium             4.259707e-02
# education_College            4.922172e-02
# education_Master             2.954872e-02
# marital_status_Single        9.462825e-03
# policy_Corporate L2          2.816731e-02
# policy_Corporate L3          2.086841e-02
# policy_Personal L3           4.276820e-02
# renew_offer_type_Offer2      3.923400e-13
# renew_offer_type_Offer3      3.827024e-04
# renew_offer_type_Offer4      7.756365e-11
# vehicle_class_SUV            5.807066e-03
# vehicle_size_Small           3.317256e-02
# dtype: float64

# %% [markdown]
# ### Model 2 Interpretation
# * The model has an R-squared of 0.247, which while moderately better than model 1, does not explain enough variation in our data to be meaningful.
# * There are 5 more statistically significant predictors than seen with model 1.
# * The model also suggests that there are strong multicollinearity problems that make it difficult to determine the effect of each preditor on the CLV.

# %% [markdown]
# ## Model 3) Linear Regression: Including Interaction Terms

# %% [markdown]
# From the EDA, we know that vast amount of variation, skew, and spread comes from having two policies. We will create a dummy variable to account for this. Then, we re-run the full model (Model 1), but include the interaction between policy premium and a Y/N flag for two policies:

# %%
X_3 = clv_df_model_1.drop(columns = 'customer_lifetime_value') 
y_3 = clv_df_model_1['customer_lifetime_value'] 

X_3['two_policies'] = (X_3['number_of_policies'] == 2).astype(int)
X_3['premium_policy_intrxn'] = X_3['two_policies'] * X_3['monthly_premium_auto']

X_3 = sm.add_constant(X_3)
model_3 = sm.OLS(y_3, X_3).fit()
print(model_3.summary())
# Out:
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     customer_lifetime_value   R-squared:                       0.666
# Model:                                 OLS   Adj. R-squared:                  0.664
# Method:                      Least Squares   F-statistic:                     361.6
# Date:                     Wed, 19 Nov 2025   Prob (F-statistic):               0.00
# Time:                             19:17:36   Log-Likelihood:                -88657.
# No. Observations:                     9134   AIC:                         1.774e+05
# Df Residuals:                         9083   BIC:                         1.778e+05
# Df Model:                               50
# Covariance Type:                 nonrobust
# ===================================================================================================
#                                       coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------
# const                           -1663.3058    578.907     -2.873      0.004   -2798.095    -528.517
# income                              0.0005      0.002      0.198      0.843      -0.004       0.005
# monthly_premium_auto               49.6153      6.392      7.763      0.000      37.086      62.144
# months_since_last_claim            10.3512      4.160      2.488      0.013       2.197      18.505
# months_since_policy_inception       1.2007      1.511      0.795      0.427      -1.761       4.162
# number_of_open_complaints        -151.3425     46.015     -3.289      0.001    -241.542     -61.143
# number_of_policies                539.7670     18.145     29.747      0.000     504.199     575.335
# total_claim_amount                 -0.1140      0.301     -0.379      0.705      -0.704       0.476
# state_California                  -56.5633    120.215     -0.471      0.638    -292.211     179.085
# state_Nevada                       61.7472    165.726      0.373      0.709    -263.112     386.607
# state_Oregon                      -30.4850    124.413     -0.245      0.806    -274.363     213.393
# state_Washington                   91.2037    171.341      0.532      0.595    -244.663     427.070
# customer_response_to_offer_Yes   -244.5631    131.645     -1.858      0.063    -502.617      13.490
# coverage_Extended                  12.4185    158.231      0.078      0.937    -297.750     322.587
# coverage_Premium                 -215.1255    334.834     -0.642      0.521    -871.475     441.224
# education_College                 -64.2475    108.655     -0.591      0.554    -277.235     148.740
# education_Doctor                  108.3518    230.397      0.470      0.638    -343.278     559.982
# education_High School or Below    230.5838    110.052      2.095      0.036      14.857     446.311
# education_Master                  286.8786    166.833      1.720      0.086     -40.152     613.909
# employment_status_Employed        545.9680    224.948      2.427      0.015     105.020     986.916
# employment_status_Medical Leave   277.9124    276.826      1.004      0.315    -264.729     820.554
# employment_status_Retired         124.8099    319.025      0.391      0.696    -500.551     750.171
# employment_status_Unemployed       46.0596    226.930      0.203      0.839    -398.775     490.894
# gender_M                         -310.9331     84.395     -3.684      0.000    -476.366    -145.500
# location_code_Suburban              8.6935    167.155      0.052      0.959    -318.968     336.355
# location_code_Urban               187.7243    153.197      1.225      0.220    -112.576     488.024
# marital_status_Married            -11.1048    123.623     -0.090      0.928    -253.434     231.224
# marital_status_Single            -253.6772    143.255     -1.771      0.077    -534.489      27.135
# policy_type_Personal Auto          -9.3907    162.941     -0.058      0.954    -328.792     310.010
# policy_type_Special Auto           81.0831    230.146      0.352      0.725    -370.055     532.222
# policy_Corporate L2              -273.0065    266.945     -1.023      0.306    -796.279     250.266
# policy_Corporate L3               -24.5618    245.252     -0.100      0.920    -505.311     456.188
# policy_Personal L1                -63.1809    103.834     -0.608      0.543    -266.718     140.357
# policy_Personal L2                 34.3960     89.997      0.382      0.702    -142.018     210.810
# policy_Personal L3                 19.3943     81.658      0.238      0.812    -140.673     179.461
# policy_Special L1                -440.4887    389.639     -1.131      0.258   -1204.269     323.291
# policy_Special L2                  69.4735    281.733      0.247      0.805    -482.787     621.734
# policy_Special L3                 452.0983    290.831      1.555      0.120    -117.995    1022.192
# renew_offer_type_Offer2            69.1227    105.312      0.656      0.512    -137.313     275.558
# renew_offer_type_Offer3           109.6810    127.220      0.862      0.389    -139.699     359.061
# renew_offer_type_Offer4             8.7107    148.461      0.059      0.953    -282.307     299.728
# sales_channel_Branch              110.9985    104.612      1.061      0.289     -94.065     316.062
# sales_channel_Call Center          96.6921    118.227      0.818      0.413    -135.059     328.444
# sales_channel_Web                  19.9084    130.820      0.152      0.879    -236.528     276.344
# vehicle_class_Luxury Car          658.2378    878.468      0.749      0.454   -1063.758    2380.233
# vehicle_class_Luxury SUV         1287.2283    870.732      1.478      0.139    -419.602    2994.058
# vehicle_class_SUV                 521.3176    290.062      1.797      0.072     -47.269    1089.904
# vehicle_class_Sports Car          906.3905    333.964      2.714      0.007     251.747    1561.034
# vehicle_class_Two-Door Car         -6.5126    109.213     -0.060      0.952    -220.596     207.570
# vehicle_size_Medsize               95.6996    139.452      0.686      0.493    -177.658     369.057
# vehicle_size_Small                141.6588    162.272      0.873      0.383    -176.431     459.748
# two_policies                     1611.6116    284.738      5.660      0.000    1053.461    2169.762
# premium_policy_intrxn             100.7813      2.862     35.217      0.000      95.172     106.391
# ==============================================================================
# Omnibus:                     5481.628   Durbin-Watson:                   1.950
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            88388.437
# Skew:                           2.583   Prob(JB):                         0.00
# Kurtosis:                      17.337   Cond. No.                     1.29e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.29e-19. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %% [markdown]
# #### Can we achieve similiar results with a reduced model, that only includes the interaction term?

# %%
clv_df_model_3a = clv_df_model_1
clv_df_model_3a['two_policies'] = (clv_df_model_3a['number_of_policies'] == 2).astype(int)

# %%
model_3a = smf.ols(formula='customer_lifetime_value ~ (monthly_premium_auto) * (two_policies)'
                             , data=clv_df_model_3a).fit()

# %%
print(model_3a.summary())
# Out:
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     customer_lifetime_value   R-squared:                       0.627
# Model:                                 OLS   Adj. R-squared:                  0.627
# Method:                      Least Squares   F-statistic:                     5108.
# Date:                     Wed, 19 Nov 2025   Prob (F-statistic):               0.00
# Time:                             19:17:36   Log-Likelihood:                -89160.
# No. Observations:                     9134   AIC:                         1.783e+05
# Df Residuals:                         9130   BIC:                         1.784e+05
# Df Model:                                3
# Covariance Type:                 nonrobust
# =====================================================================================================
#                                         coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------
# Intercept                           291.8798    145.409      2.007      0.045       6.846     576.914
# monthly_premium_auto                 54.9811      1.462     37.609      0.000      52.115      57.847
# two_policies                        835.3711    297.807      2.805      0.005     251.603    1419.140
# monthly_premium_auto:two_policies   101.5242      3.003     33.805      0.000      95.637     107.411
# ==============================================================================
# Omnibus:                     4748.533   Durbin-Watson:                   1.956
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            56385.528
# Skew:                           2.225   Prob(JB):                         0.00
# Kurtosis:                      14.329   Cond. No.                         722.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
y_hat = model_3a.predict()

plt.figure(figsize=(6,6))

plt.plot(y_hat, model_3a.resid, 'ko', mec='w')
plt.axhline(0, color='r', linestyle='dashed', lw=2)

plt.xlabel('Predicted CLV', fontsize=16)
plt.ylabel('Residual CLV', fontsize=16)

plt.tick_params(labelsize=14)

plt.show()

# %% [markdown]
# ### Model 3 Interpretation:
# * Addressing the interaction between policy count and Monthly Premium provided a significant lift on explanatory power: R-squared went from 0.169 to 0.666 simply by adding an interaction term
# * This interaction term alone, as a single variate linear regression, has an R-Squared of 0.627
# * The residuals however, are not quite random-- something is still failing to fully explain the variation
# * Capturing the two policy group is a key to successfully modeling CLV

# %% [markdown]
# ## Model 4) Individual Linear Regression Models per Policy Count

# %%
clv_df_1pol = clv_df.loc[clv_df['number_of_policies'] == 1] 
clv_df_2pol = clv_df.loc[clv_df['number_of_policies'] == 2] 
clv_df_3pol = clv_df.loc[clv_df['number_of_policies'] == 3] 
clv_df_4pol = clv_df.loc[clv_df['number_of_policies'] == 4] 
clv_df_5pol = clv_df.loc[clv_df['number_of_policies'] == 5] 
clv_df_6pol = clv_df.loc[clv_df['number_of_policies'] == 6] 
clv_df_7pol = clv_df.loc[clv_df['number_of_policies'] == 7] 
clv_df_8pol = clv_df.loc[clv_df['number_of_policies'] == 8] 
clv_df_9pol = clv_df.loc[clv_df['number_of_policies'] == 9]

# %%
clv_df_1pol= pd.get_dummies(clv_df_1pol, drop_first=True)
bool_cols = clv_df_1pol.select_dtypes(include='bool').columns
clv_df_1pol[bool_cols] = clv_df_1pol[bool_cols].astype(int)
X_1pol = clv_df_1pol.drop(columns = 'customer_lifetime_value') # X is the predictor variable
y_1pol = clv_df_1pol['customer_lifetime_value'] # y is the response variable
# One-hot encode categorical variable
# Add constant term (intercept)
X_1pol = sm.add_constant(X_1pol)
# Fit OLS model
model_1pol = sm.OLS(y_1pol, X_1pol).fit()
# Print detailed summary
print(model_1pol.summary())
# Out:
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     customer_lifetime_value   R-squared:                       0.996
# Model:                                 OLS   Adj. R-squared:                  0.996
# Method:                      Least Squares   F-statistic:                 1.595e+04
# Date:                     Wed, 19 Nov 2025   Prob (F-statistic):               0.00
# Time:                             19:17:36   Log-Likelihood:                -19317.
# No. Observations:                     3251   AIC:                         3.873e+04
# Df Residuals:                         3203   BIC:                         3.902e+04
# Df Model:                               47
# Covariance Type:                 nonrobust
# ===================================================================================================
#                                       coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------
# income                              0.0013   9.65e-05     13.308      0.000       0.001       0.001
# monthly_premium_auto               39.8558      0.242    164.982      0.000      39.382      40.329
# months_since_last_claim             0.4013      0.163      2.458      0.014       0.081       0.721
# months_since_policy_inception      -0.0313      0.059     -0.527      0.598      -0.148       0.085
# number_of_open_complaints         -64.3879      1.773    -36.325      0.000     -67.863     -60.912
# number_of_policies               -181.4790     21.905     -8.285      0.000    -224.429    -138.529
# total_claim_amount                 -0.2278      0.011    -19.936      0.000      -0.250      -0.205
# state_California                   -6.3243      4.755     -1.330      0.184     -15.648       3.000
# state_Nevada                      -14.4535      6.338     -2.281      0.023     -26.880      -2.027
# state_Oregon                       -1.8874      4.930     -0.383      0.702     -11.553       7.779
# state_Washington                   -0.6341      6.587     -0.096      0.923     -13.550      12.282
# customer_response_to_offer_Yes     -7.4453      5.081     -1.465      0.143     -17.407       2.517
# coverage_Extended                  -7.2004      6.128     -1.175      0.240     -19.216       4.815
# coverage_Premium                  -15.0661     13.024     -1.157      0.247     -40.603      10.471
# education_College                 -11.1743      4.249     -2.630      0.009     -19.504      -2.844
-20. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %%
clv_df_2pol= pd.get_dummies(clv_df_2pol, drop_first=True)
bool_cols = clv_df_2pol.select_dtypes(include='bool').columns
clv_df_2pol[bool_cols] = clv_df_2pol[bool_cols].astype(int)
X_2pol = clv_df_2pol.drop(columns = 'customer_lifetime_value') # X is the predictor variable
y_2pol = clv_df_2pol['customer_lifetime_value'] # y is the response variable
# One-hot encode categorical variable
# Add constant term (intercept)
X_2pol = sm.add_constant(X_2pol)
# Fit OLS model
model_2pol = sm.OLS(y_2pol, X_2pol).fit()
# Print detailed summary
print(model_2pol.summary())
# Out:
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     customer_lifetime_value   R-squared:                       0.340
# Model:                                 OLS   Adj. R-squared:                  0.326
# Method:                      Least Squares   F-statistic:                     24.58
# Date:                     Wed, 19 Nov 2025   Prob (F-statistic):          1.14e-166
# Time:                             19:17:36   Log-Likelihood:                -23741.
# No. Observations:                     2294   AIC:                         4.758e+04
# Df Residuals:                         2246   BIC:                         4.785e+04
# Df Model:                               47
# Covariance Type:                 nonrobust
# ===================================================================================================
#                                       coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------
# income                             -0.0063      0.010     -0.649      0.516      -0.025       0.013
# monthly_premium_auto              133.1721     24.541      5.427      0.000      85.047     181.297
# months_since_last_claim            38.9026     16.190      2.403      0.016       7.153      70.652
# months_since_policy_inception       4.1842      5.825      0.718      0.473      -7.240      15.608
# number_of_open_complaints        -305.1501    189.879     -1.607      0.108    -677.506      67.206
# number_of_policies                185.3757   1080.440      0.172      0.864   -1933.390    2304.141
# total_claim_amount                  0.8413      1.160      0.725      0.468      -1.433       3.115
# state_California                 -196.7072    467.366     -0.421      0.674   -1113.222     719.808
# state_Nevada                      543.0842    638.154      0.851      0.395    -708.349    1794.518
# state_Oregon                      -55.7663    482.398     -0.116      0.908   -1001.758     890.226
# state_Washington                  675.5944    666.030      1.014      0.311    -630.505    1981.694
# customer_response_to_offer_Yes     29.1662    507.000      0.058      0.954    -965.071    1023.403
# coverage_Extended                 -76.8937    613.378     -0.125      0.900   -1279.741    1125.954
# coverage_Premium                 -687.6154   1262.559     -0.545      0.586   -3163.521    1788.290
# education_College                -198.2340    416.836     -0.476      0.634   -1015.658     619.190
# education_Doctor                  292.2297    975.442      0.300      0.765   -1620.632    2205.091
# education_High School or Below    609.3354    425.206      1.433      0.152    -224.503    1443.174
# education_Master                  740.6089    655.424      1.130      0.259    -544.691    2025.908
# employment_status_Employed       1972.5065    845.013      2.334      0.020     315.418    3629.596
# employment_status_Medical Leave  1384.0184   1062.299      1.303      0.193    -699.171    3467.208
# employment_status_Retired        1162.5788   1162.779      1.000      0.318   -1117.655    3442.813
# employment_status_Unemployed      892.7215    855.442      1.044      0.297    -784.818    2570.261
# gender_M                        -1031.0746    327.475     -3.149      0.002   -1673.260    -388.889
# location_code_Suburban           -382.7286    648.327     -0.590      0.555   -1654.111     888.654
# location_code_Urban               143.8465    592.831      0.243      0.808   -1018.708    1306.401
# marital_status_Married           -113.1489    458.770     -0.247      0.805   -1012.806     786.508
# marital_status_Single            -437.4046    529.983     -0.825      0.409   -1476.713     601.904
# policy_type_Personal Auto          67.0924    581.859      0.115      0.908   -1073.946    1208.131
# policy_type_Special Auto          358.8864    798.212      0.450      0.653   -1206.424    1924.197
# policy_Corporate L2             -1185.5738   1014.478     -1.169      0.243   -3174.986     803.839
# policy_Corporate L3               132.3674    899.010      0.147      0.883   -1630.610    1895.345
# policy_Personal L1               -194.6713    395.087     -0.493      0.622    -969.445     580.103
# policy_Personal L2                154.8539    334.852      0.462      0.644    -501.798     811.506
# policy_Personal L3                106.9099    305.342      0.350      0.726    -491.872     705.692
# policy_Special L1               -1148.7972   1262.919     -0.910      0.363   -3625.407    1327.813
# policy_Special L2                 259.4451   1023.728      0.253      0.800   -1748.106    2266.996
# policy_Special L3                1248.2385   1008.859      1.237      0.216    -730.155    3226.632
# renew_offer_type_Offer2           667.7687    409.119      1.632      0.103    -134.523    1470.060
# renew_offer_type_Offer3           505.0476    482.971      1.046      0.296    -442.069    1452.164
# renew_offer_type_Offer4           666.3527    585.459      1.138      0.255    -481.744    1814.449
# sales_channel_Branch              292.7310    399.311      0.733      0.464    -490.327    1075.789
# sales_channel_Call Center         149.6303    453.848      0.330      0.742    -740.376    1039.636
# sales_channel_Web                -147.5377    521.157     -0.283      0.777   -1169.538     874.462
# vehicle_class_Luxury Car         1991.6176   3361.556      0.592      0.554   -4600.464    8583.699
# vehicle_class_Luxury SUV         4638.0676   3361.765      1.380      0.168   -1954.424    1.12e+04
# vehicle_class_SUV                1474.1741   1097.775      1.343      0.179    -678.586    3626.935
# vehicle_class_Sports Car         2972.2788   1284.937      2.313      0.021     452.491    5492.067
# vehicle_class_Two-Door Car        -17.8096    418.824     -0.043      0.966    -839.132     803.513
# vehicle_size_Medsize              332.5875    552.433      0.602      0.547    -750.745    1415.920
# vehicle_size_Small                255.3794    643.133      0.397      0.691   -1005.817    1516.576
# ==============================================================================
# Omnibus:                      572.943   Durbin-Watson:                   1.935
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1239.375
# Skew:                           1.427   Prob(JB):                    7.47e-270
# Kurtosis:                       5.197   Cond. No.                     1.00e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 5.2e-20. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %%
clv_df_3pol= pd.get_dummies(clv_df_3pol, drop_first=True)
bool_cols = clv_df_3pol.select_dtypes(include='bool').columns
clv_df_3pol[bool_cols] = clv_df_3pol[bool_cols].astype(int)
X_3pol = clv_df_3pol.drop(columns = 'customer_lifetime_value') # X is the predictor variable
y_3pol = clv_df_3pol['customer_lifetime_value'] # y is the response variable
# One-hot encode categorical variable
# Add constant term (intercept)
X_3pol = sm.add_constant(X_3pol)
# Fit OLS model
model_3pol = sm.OLS(y_3pol, X_3pol).fit()
# Print detailed summary
print(model_3pol.summary())
# Out:
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     customer_lifetime_value   R-squared:                       0.995
# Model:                                 OLS   Adj. R-squared:                  0.995
# Method:                      Least Squares   F-statistic:                     4620.
# Date:                     Wed, 19 Nov 2025   Prob (F-statistic):               0.00
# Time:                             19:17:36   Log-Likelihood:                -7645.8
# No. Observations:                     1168   AIC:                         1.539e+04
# Df Residuals:                         1120   BIC:                         1.563e+04
# Df Model:                               47
# Covariance Type:                 nonrobust
# ===================================================================================================
#                                       coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------
# income                              0.0027      0.000      9.336      0.000       0.002       0.003
# monthly_premium_auto               79.3388      0.867     91.530      0.000      77.638      81.039
# months_since_last_claim            -0.4717      0.518     -0.910      0.363      -1.489       0.545
# months_since_policy_inception      -0.4951      0.185     -2.676      0.008      -0.858      -0.132
# number_of_open_complaints        -110.6296      5.619    -19.687      0.000    -121.655     -99.604
# number_of_policies               -118.8183     24.953     -4.762      0.000    -167.778     -69.858
# total_claim_amount                 -0.2982      0.040     -7.490      0.000      -0.376      -0.220
Durbin-Watson:                   2.032
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2535.743
# Skew:                          -1.128   Prob(JB):                         0.00
# Kurtosis:                       9.857   Cond. No.                     1.00e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 2.97e-20. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %% [markdown]
# #### Repeat for remaining policy counts, uncomment the final print line to see results

# %%
clv_df_4pol= pd.get_dummies(clv_df_4pol, drop_first=True)
bool_cols = clv_df_4pol.select_dtypes(include='bool').columns
clv_df_4pol[bool_cols] = clv_df_4pol[bool_cols].astype(int)
X_4pol = clv_df_4pol.drop(columns = 'customer_lifetime_value') # X is the predictor variable
y_4pol = clv_df_4pol['customer_lifetime_value'] # y is the response variable
# One-hot encode categorical variable
# Add constant term (intercept)
X_4pol = sm.add_constant(X_4pol)
# Fit OLS model
model_4pol = sm.OLS(y_4pol, X_4pol).fit()
# Print detailed summary
# print(model_4pol.summary())

# %%
clv_df_5pol= pd.get_dummies(clv_df_5pol, drop_first=True)
bool_cols = clv_df_5pol.select_dtypes(include='bool').columns
clv_df_5pol[bool_cols] = clv_df_5pol[bool_cols].astype(int)
X_5pol = clv_df_5pol.drop(columns = 'customer_lifetime_value') # X is the predictor variable
y_5pol = clv_df_5pol['customer_lifetime_value'] # y is the response variable
# One-hot encode categorical variable
# Add constant term (intercept)
X_5pol = sm.add_constant(X_5pol)
# Fit OLS model
model_5pol = sm.OLS(y_5pol, X_5pol).fit()
# Print detailed summary
# print(model_5pol.summary())

# %%
clv_df_6pol= pd.get_dummies(clv_df_6pol, drop_first=True)
bool_cols = clv_df_6pol.select_dtypes(include='bool').columns
clv_df_6pol[bool_cols] = clv_df_6pol[bool_cols].astype(int)
X_6pol = clv_df_6pol.drop(columns = 'customer_lifetime_value') # X is the predictor variable
y_6pol = clv_df_6pol['customer_lifetime_value'] # y is the response variable
# One-hot encode categorical variable
# Add constant term (intercept)
X_6pol = sm.add_constant(X_6pol)
# Fit OLS model
model_6pol = sm.OLS(y_6pol, X_6pol).fit()
# Print detailed summary
# print(model_6pol.summary())

# %%
clv_df_7pol= pd.get_dummies(clv_df_7pol, drop_first=True)
bool_cols = clv_df_7pol.select_dtypes(include='bool').columns
clv_df_7pol[bool_cols] = clv_df_7pol[bool_cols].astype(int)
X_7pol = clv_df_7pol.drop(columns = 'customer_lifetime_value') # X is the predictor variable
y_7pol = clv_df_7pol['customer_lifetime_value'] # y is the response variable
# One-hot encode categorical variable
# Add constant term (intercept)
X_7pol = sm.add_constant(X_7pol)
# Fit OLS model
model_7pol = sm.OLS(y_7pol, X_7pol).fit()
# Print detailed summary
# print(model_7pol.summary())

# %%
clv_df_8pol= pd.get_dummies(clv_df_8pol, drop_first=True)
bool_cols = clv_df_8pol.select_dtypes(include='bool').columns
clv_df_8pol[bool_cols] = clv_df_8pol[bool_cols].astype(int)
X_8pol = clv_df_8pol.drop(columns = 'customer_lifetime_value') # X is the predictor variable
y_8pol = clv_df_8pol['customer_lifetime_value'] # y is the response variable
# One-hot encode categorical variable
# Add constant term (intercept)
X_8pol = sm.add_constant(X_8pol)
# Fit OLS model
model_8pol = sm.OLS(y_8pol, X_8pol).fit()
# Print detailed summary
# print(model_8pol.summary())

# %%
clv_df_9pol= pd.get_dummies(clv_df_9pol, drop_first=True)
bool_cols = clv_df_9pol.select_dtypes(include='bool').columns
clv_df_9pol[bool_cols] = clv_df_9pol[bool_cols].astype(int)
X_9pol = clv_df_9pol.drop(columns = 'customer_lifetime_value') # X is the predictor variable
y_9pol = clv_df_9pol['customer_lifetime_value'] # y is the response variable
# One-hot encode categorical variable
# Add constant term (intercept)
X_9pol = sm.add_constant(X_9pol)
# Fit OLS model
model_9pol = sm.OLS(y_9pol, X_9pol).fit()
# Print detailed summary
print(model_9pol.summary())
# Out:
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     customer_lifetime_value   R-squared:                       0.997
# Model:                                 OLS   Adj. R-squared:                  0.996
# Method:                      Least Squares   F-statistic:                     2347.
# Date:                     Wed, 19 Nov 2025   Prob (F-statistic):               0.00
# Time:                             19:17:37   Log-Likelihood:                -2681.3
# No. Observations:                      416   AIC:                             5459.
# Df Residuals:                          368   BIC:                             5652.
# Df Model:                               47
# Covariance Type:                 nonrobust
# ===================================================================================================
#                                       coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------
# income                              0.0027      0.001      5.101      0.000       0.002       0.004
# monthly_premium_auto               76.0159      1.214     62.622      0.000      73.629      78.403
# months_since_last_claim             0.9695      0.858      1.131      0.259      -0.717       2.656
# months_since_policy_inception       0.1505      0.322      0.467      0.641      -0.483       0.784
# number_of_open_complaints        -114.4802     10.467    -10.938      0.000    -135.062     -93.898
# number_of_policies                 -2.8479     13.010     -0.219      0.827     -28.431      22.735
# total_claim_amount                 -0.4361      0.071     -6.126      0.000      -0.576      -0.296
# state_California                   20.3160     23.192      0.876      0.382     -25.289      65.920
# state_Nevada                        5.5799     34.574      0.161      0.872     -62.408      73.568
# state_Oregon                        1.4867     23.916      0.062      0.950     -45.542      48.515
# state_Washington                  -24.6386     31.440     -0.784      0.434     -86.464      37.186
# customer_response_to_offer_Yes     21.2460     27.915      0.761      0.447     -33.647      76.139
# coverage_Extended                  90.1585     30.080      2.997      0.003      31.009     149.308
# coverage_Premium                  125.1797     66.293      1.888      0.060      -5.180     255.540
# education_College                 -62.6751     22.745     -2.756      0.006    -107.401     -17.949
# education_Doctor                  125.5503     47.684      2.633      0.009      31.784     219.317
# education_High School or Below      6.2774     22.589      0.278      0.781     -38.142      50.697
# education_Master                   80.8517     36.629      2.207      0.028       8.823     152.881
# employment_status_Employed        192.2700     44.434      4.327      0.000     104.895     279.645
# employment_status_Medical Leave  -100.7222     55.576     -1.812      0.071    -210.009       8.564
# employment_status_Retired        -441.2028     66.286     -6.656      0.000    -571.549    -310.856
# employment_status_Unemployed     -360.2451     46.458     -7.754      0.000    -451.601    -268.889
# gender_M                          -73.4480     18.030     -4.074      0.000    -108.903     -37.993
# location_code_Suburban            143.2942     36.742      3.900      0.000      71.044     215.544
# location_code_Urban                83.9536     32.525      2.581      0.010      19.996     147.912
# marital_status_Married             72.3835     26.849      2.696      0.007      19.588     125.179
# marital_status_Single            -103.9362     31.388     -3.311      0.001    -165.659     -42.214
# policy_type_Personal Auto         -18.8439     31.627     -0.596      0.552     -81.037      43.349
# policy_type_Special Auto          -44.3255     72.692     -0.610      0.542    -187.270      98.619
# policy_Corporate L2               -14.9451     53.957     -0.277      0.782    -121.047      91.157
# policy_Corporate L3               -74.1881     46.905     -1.582      0.115    -166.423      18.047
# policy_Personal L1                -22.0315     19.717     -1.117      0.265     -60.805      16.742
# policy_Personal L2                 -6.9160     18.161     -0.381      0.704     -42.628      28.796
# policy_Personal L3                 10.1036     15.646      0.646      0.519     -20.663      40.871
# policy_Special L1                  22.5159    142.325      0.158      0.874    -257.356     302.388
# policy_Special L2                -102.7146    139.212     -0.738      0.461    -376.465     171.036
# policy_Special L3                  35.8732     89.030      0.403      0.687    -139.198     210.945
# renew_offer_type_Offer2           -16.6733     20.660     -0.807      0.420     -57.300      23.953
# renew_offer_type_Offer3            53.4864     24.701      2.165      0.031       4.913     102.060
# renew_offer_type_Offer4           -31.5168     37.178     -0.848      0.397    -104.625      41.591
# sales_channel_Branch               35.8881     21.624      1.660      0.098      -6.634      78.410
# sales_channel_Call Center         -17.6045     25.464     -0.691      0.490     -67.678      32.469
# sales_channel_Web                  70.5590     24.740      2.852      0.005      21.910     119.208
# vehicle_class_Luxury Car          533.5451    172.061      3.101      0.002     195.198     871.892
# vehicle_class_Luxury SUV          228.8396    185.185      1.236      0.217    -135.313     592.993
# vehicle_class_SUV                 117.7989     58.661      2.008      0.045       2.446     233.151
# vehicle_class_Sports Car           83.8163     64.699      1.295      0.196     -43.411     211.043
# vehicle_class_Two-Door Car         41.6128     23.992      1.734      0.084      -5.566      88.792
# vehicle_size_Medsize                6.6079     29.515      0.224      0.823     -51.432      64.648
# vehicle_size_Small                -26.0313     34.140     -0.762      0.446     -93.165      41.102
# ==============================================================================
# Omnibus:                       57.175   Durbin-Watson:                   1.907
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              230.674
# Skew:                          -0.523   Prob(JB):                     8.12e-51
# Kurtosis:                       6.495   Cond. No.                     1.00e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 9.33e-21. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %% [markdown]
# ### Model 4 Interpretation:
# * We see incredible results for each individual policy count, except for when a customer has 2 policies
# * Using linear regression we can produce an R-Squared of 0.99 for customers with 1 or 3 policies
# * The same linear regression model for customers with 2 policies has an R-Squared of 0.340
# * The same is true for remaining policy counts, results for policies 4-8 were hidden to avoid redundancy

# %% [markdown]
# ## Model 5) Create Two Separate Linear Regression Models: Excluding 2 Policies and Only Two Policies

# %% [markdown]
# Model 5a will be for all customers excluding those with two policies

# %%
clv_df_exclude_2 = clv_df.loc[clv_df['number_of_policies'] != 2]

# %% [markdown]
# Model 5b will be for customers with exactly two policies

# %%
clv_df_is_2 = clv_df.loc[clv_df['number_of_policies'] == 2]

# %%
# One-hot encode categorical variable
clv_df_exclude_2= pd.get_dummies(clv_df_exclude_2, drop_first=True)
bool_cols = clv_df_exclude_2.select_dtypes(include='bool').columns
clv_df_exclude_2[bool_cols] = clv_df_exclude_2[bool_cols].astype(int)
X_5a = clv_df_exclude_2.drop(columns = 'customer_lifetime_value') # X is the predictor variable
y_5a = clv_df_exclude_2['customer_lifetime_value'] # y is the response variable

# Add constant term (intercept)
X_5a = sm.add_constant(X_5a)
# Fit OLS model
model_5a = sm.OLS(y_5a, X_5a).fit()
# Print detailed summary
print(model_5a.summary())
# Out:
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     customer_lifetime_value   R-squared:                       0.796
# Model:                                 OLS   Adj. R-squared:                  0.795
# Method:                      Least Squares   F-statistic:                     553.4
# Date:                     Wed, 19 Nov 2025   Prob (F-statistic):               0.00
# Time:                             19:17:37   Log-Likelihood:                -58336.
# No. Observations:                     6840   AIC:                         1.168e+05
# Df Residuals:                         6791   BIC:                         1.171e+05
# Df Model:                               48
# Covariance Type:                 nonrobust
# ===================================================================================================
#                                       coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------
# const                           -1437.7716    206.446     -6.964      0.000   -1842.471   -1033.072
# income                              0.0034      0.001      3.959      0.000       0.002       0.005
# monthly_premium_auto               55.0482      2.270     24.251      0.000      50.599      59.498
# months_since_last_claim             0.0495      1.481      0.033      0.973      -2.853       2.952
# months_since_policy_inception      -0.0211      0.539     -0.039      0.969      -1.077       1.035
# number_of_open_complaints        -104.7489     16.116     -6.500      0.000    -136.341     -73.156
# number_of_policies                534.8462      5.615     95.253      0.000     523.839     545.853
# total_claim_amount                 -0.4476      0.107     -4.166      0.000      -0.658      -0.237
# state_California                   16.0931     42.705      0.377      0.706     -67.623      99.809
# state_Nevada                     -105.7655     59.034     -1.792      0.073    -221.490       9.959
# state_Oregon                       -6.7490     44.282     -0.152      0.879     -93.556      80.058
# state_Washington                  -94.4916     60.932     -1.551      0.121    -213.938      24.955
# customer_response_to_offer_Yes   -250.6079     47.215     -5.308      0.000    -343.164    -158.052
# coverage_Extended                  66.5961     56.327      1.182      0.237     -43.822     177.014
# coverage_Premium                  -10.3004    120.513     -0.085      0.932    -246.544     225.943
# education_College                  39.2553     38.820      1.011      0.312     -36.843     115.354
# education_Doctor                  136.8721     80.007      1.711      0.087     -19.966     293.710
# education_High School or Below    108.3625     39.310      2.757      0.006      31.303     185.422
# education_Master                  234.5560     59.253      3.959      0.000     118.401     350.711
# employment_status_Employed         59.7448     80.993      0.738      0.461     -99.027     218.517
# employment_status_Medical Leave  -133.8238     98.968     -1.352      0.176    -327.832      60.184
# employment_status_Retired        -287.4911    116.258     -2.473      0.013    -515.393     -59.589
# employment_status_Unemployed     -197.8731     81.653     -2.423      0.015    -357.939     -37.807
# gender_M                          -59.7876     30.082     -1.988      0.047    -118.757      -0.818
# location_code_Suburban            152.5141     59.511      2.563      0.010      35.854     269.174
# location_code_Urban               154.5485     54.578      2.832      0.005      47.558     261.539
# marital_status_Married             40.2329     44.700      0.900      0.368     -47.394     127.860
# marital_status_Single            -137.2444     51.841     -2.647      0.008    -238.870     -35.619
# policy_type_Personal Auto         -39.3667     59.739     -0.659      0.510    -156.473      77.740
# policy_type_Special Auto          -13.8489     85.688     -0.162      0.872    -181.825     154.127
# policy_Corporate L2                -3.9380     96.020     -0.041      0.967    -192.167     184.291
# policy_Corporate L3               -72.8384     89.168     -0.817      0.414    -247.635     101.958
# policy_Personal L1                 -9.8073     37.214     -0.264      0.792     -82.758      63.143
# policy_Personal L2                 -6.3723     32.534     -0.196      0.845     -70.149      57.405
# policy_Personal L3                -23.1871     29.457     -0.787      0.431     -80.933      34.559
# policy_Special L1                  -0.4235    149.762     -0.003      0.998    -294.003     293.156
# policy_Special L2                  24.4903    103.017      0.238      0.812    -177.456     226.436
# policy_Special L3                 -37.9158    108.181     -0.350      0.726    -249.984     174.152
# renew_offer_type_Offer2          -167.6478     37.584     -4.461      0.000    -241.325     -93.971
# renew_offer_type_Offer3           -79.9601     45.657     -1.751      0.080    -169.463       9.543
# renew_offer_type_Offer4          -225.9645     52.542     -4.301      0.000    -328.962    -122.967
# sales_channel_Branch               40.7386     37.462      1.087      0.277     -32.698     114.175
# sales_channel_Call Center          59.9183     42.210      1.420      0.156     -22.827     142.663
# sales_channel_Web                  45.9165     46.239      0.993      0.321     -44.726     136.559
# vehicle_class_Luxury Car          377.0727    314.183      1.200      0.230    -238.824     992.969
# vehicle_class_Luxury SUV          318.1297    310.578      1.024      0.306    -290.700     926.959
# vehicle_class_SUV                 215.3615    104.174      2.067      0.039      11.148     419.575
# vehicle_class_Sports Car          166.5064    119.258      1.396      0.163     -67.277     400.290
# vehicle_class_Two-Door Car        -52.2897     39.049     -1.339      0.181    -128.838      24.258
# vehicle_size_Medsize               26.3830     49.448      0.534      0.594     -70.551     123.317
# vehicle_size_Small                117.3731     57.571      2.039      0.042       4.515     230.231
# ==============================================================================
# Omnibus:                      412.371   Durbin-Watson:                   2.012
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              514.384
# Skew:                           0.588   Prob(JB):                    2.01e-112
# Kurtosis:                       3.648   Cond. No.                     1.28e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 9.8e-20. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %%
# One-hot encode categorical variable
clv_df_is_2= pd.get_dummies(clv_df_is_2, drop_first=True)
bool_cols = clv_df_is_2.select_dtypes(include='bool').columns
clv_df_is_2[bool_cols] = clv_df_is_2[bool_cols].astype(int)
X_5b = clv_df_is_2.drop(columns = 'customer_lifetime_value') # X is the predictor variable
y_5b = clv_df_is_2['customer_lifetime_value'] # y is the response variable

# Add constant term (intercept)
X_5b = sm.add_constant(X_5b)
# Fit OLS model
model_5b = sm.OLS(y_5b, X_5b).fit()
# Print detailed summary
print(model_5b.summary())
# Out:
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     customer_lifetime_value   R-squared:                       0.340
# Model:                                 OLS   Adj. R-squared:                  0.326
# Method:                      Least Squares   F-statistic:                     24.58
# Date:                     Wed, 19 Nov 2025   Prob (F-statistic):          1.14e-166
# Time:                             19:17:37   Log-Likelihood:                -23741.
# No. Observations:                     2294   AIC:                         4.758e+04
# Df Residuals:                         2246   BIC:                         4.785e+04
# Df Model:                               47
# Covariance Type:                 nonrobust
# ===================================================================================================
#                                       coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------
# income                             -0.0063      0.010     -0.649      0.516      -0.025       0.013
# monthly_premium_auto              133.1721     24.541      5.427      0.000      85.047     181.297
# months_since_last_claim            38.9026     16.190      2.403      0.016       7.153      70.652
# months_since_policy_inception       4.1842      5.825      0.718      0.473      -7.240      15.608
# number_of_open_complaints        -305.1501    189.879     -1.607      0.108    -677.506      67.206
# number_of_policies                185.3757   1080.440      0.172      0.864   -1933.390    2304.141
# total_claim_amount                  0.8413      1.160      0.725      0.468      -1.433       3.115
# state_California                 -196.7072    467.366     -0.421      0.674   -1113.222     719.808
# state_Nevada                      543.0842    638.154      0.851      0.395    -708.349    1794.518
Durbin-Watson:                   1.935
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1239.375
# Skew:                           1.427   Prob(JB):                    7.47e-270
# Kurtosis:                       5.197   Cond. No.                     1.00e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 5.2e-20. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %%
model5_pvals = pd.DataFrame({
    'Model5a_pval': model_5a.pvalues.round(3),
    'Model5b_pval': model_5b.pvalues.round(3)
})
significant_both = model5_pvals[(model5_pvals['Model5a_pval'] < 0.05) | 
                            (model5_pvals['Model5b_pval'] < 0.05)]

print(significant_both)
# Out:
#                                 Model5a_pval  Model5b_pval
# const                                  0.000           NaN
# customer_response_to_offer_Yes         0.000         0.954
# education_High School or Below         0.006         0.152
# education_Master                       0.000         0.259
# employment_status_Employed             0.461         0.020
# employment_status_Retired              0.013         0.318
# employment_status_Unemployed           0.015         0.297
# gender_M                               0.047         0.002
# income                                 0.000         0.516
# location_code_Suburban                 0.010         0.555
# location_code_Urban                    0.005         0.808
# marital_status_Single                  0.008         0.409
# monthly_premium_auto                   0.000         0.000
# months_since_last_claim                0.973         0.016
# number_of_open_complaints              0.000         0.108
# number_of_policies                     0.000         0.864
# renew_offer_type_Offer2                0.000         0.103
# renew_offer_type_Offer4                0.000         0.255
# total_claim_amount                     0.000         0.468
# vehicle_class_SUV                      0.039         0.179
# vehicle_class_Sports Car               0.163         0.021
# vehicle_size_Small                     0.042         0.691

# %% [markdown]
# ### Model 5 Interpretation:
# * Excluding the customers with two policies (Model 5a) we see an R-Squared of 0.796
# * The R-Squared for customers with exactly two policies (Model 5b) has an R-Squared of 0.340
# * This indicates that our linear regression model works very well when a customer does not have two policies

# %% [markdown]
# ## Model 6) Random Forest

# %% [markdown]
# Using the full dataset, but with a Random Forest model:

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, r2_score

# %%
clv_df_model_6 = clv_df_model_1.drop(columns = ['two_policies'])

# %%
X_rf = clv_df_model_6.drop(columns = 'customer_lifetime_value') 
y_rf = clv_df_model_6['customer_lifetime_value']

# %%
X_train, X_test, y_train, y_test = train_test_split(X_rf, y_rf, test_size=0.2, random_state=1)

# %%
rf_model = RandomForestRegressor()
rf_model.fit(X_train, y_train)
# Out:
# RandomForestRegressor()

# %%
y_train.shape
# Out:
# (7307,)

# %%
y_pred = rf_model.predict(X_test)

# %%
r2 = r2_score(y_test, y_pred)
print(f"R² Score of train set: {r2}")
# Out:
# R² Score of train set: 0.6839922640311104

# %% [markdown]
# ### Random Forest without 2 policies

# %%
rf_no_2_policy = clv_df_model_1[clv_df_model_1['two_policies'] == 0 ]

# %%
X_hat = rf_no_2_policy.drop(columns = 'customer_lifetime_value') 
y2 = rf_no_2_policy['customer_lifetime_value'] 
X_train2, X_test2, y_train2, y_test2 = train_test_split(X_hat, y2, test_size=0.2, random_state=1)

# %%
rf_model2 = RandomForestRegressor()
rf_model2.fit(X_train2, y_train2)
# Out:
# RandomForestRegressor()

# %%
y_pred2 = rf_model2.predict(X_test2)
r2 = r2_score(y_test2, y_pred2)
print(f"R² Score of train set: {r2}")
# Out:
# R² Score of train set: 0.995971759881266

# %% [markdown]
# ### Model 6 Interpretation:
# * For the best possible results, in one model, we recommend the Random Forest model be applied so long as the customer in question does not have exactly two policies
# * For the most explainability, we recommend using the linear regression model that corresponds to the number of policies a customer has (Model 4)
# * Significant additional research is needed to identify the root cause of the instability of modeling CLV for customers with exactly two policies
